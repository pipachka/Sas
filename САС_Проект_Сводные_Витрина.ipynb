# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Функция ниже собирает параметры для сводных таблиц, а так же витрине.

# %%
def generate_table(df, column_name = "МесяцДатыЗаказа"): 
    columns_list = [column_name, 'Выручка', 'Абсолютная маржа', 'Маржа', 'Средняя маржа',
                                 'Средний чек', 'Кол-во чеков', 'Кол-во товаров', 
                                 'Среднее кол-во товаров в  чеке',
                                 'Кол-во уникальных клиентов', 'Ценность клиента']
    unique_values = df[column_name].unique()
    total = pd.DataFrame(columns=columns_list)
    for val in unique_values:
        list_of_values = [val] 
        filtered_df = df[df[column_name] == val] # Подсчет значений
        profit = int(round(filtered_df['СуммаСтроки'].sum())) # Выручка
        list_of_values.append(profit)
        
        absmargin = int(round(filtered_df['Маржа'].sum())) # Абсолютная маржа
        list_of_values.append(absmargin)
        
        margin = absmargin/profit # Маржа                                                
        list_of_values.append(margin)
        
        df_numb_check = filtered_df['НомерЗаказаНаСайте'].unique() # # Средняя маржа !!!
        numb_check = df_numb_check.size                         
        absmargin = int(round(filtered_df['Маржа'].sum()))
        list_of_values.append(absmargin/numb_check) 
        
        avarage_bill = int(round(
            filtered_df.groupby(['НомерЗаказаНаСайте']).mean()['СуммаЗаказаНаСайте'].mean())) # Средний чек
        list_of_values.append(avarage_bill)
        
        list_of_values.append(numb_check)
        
        numb_good = filtered_df['МесяцДатыЗаказа'].size() # Кол-во товаров
        list_of_values.append(numb_good) 
        
        avarage_numb_good = int(round(
            filtered_df.groupby(['НомерЗаказаНаСайте']).count()['СуммаЗаказаНаСайте'].mean())) # Среднее кол-во товаров в чеке
        list_of_values.append(avarage_numb_good)
        
        num_of_customers = filtered_df['Телефон_new'].unique().size # Кол-во уникальных клиентов
        list_of_values.append(num_of_customers)

        value_of_customer = int(round(absmargin /num_of_customers)) # Ценность клиента
        list_of_values.append(value_of_customer) 
        
        tmp_df = pd.DataFrame([list_of_values], columns=columns_list) 
        total = total.append(tmp_df, ignore_index=True)     
    return total

# %% [markdown]
# ### Достаем таблицы по всем заказам и по выкупленным с чисткой.

# %%
df_all_orders = pd.read_csv('df_all_orders.csv', sep=';')
df_buyed_orders = pd.read_csv('df_buyed_orders.csv', sep=';')

# %% [markdown]
# ### Добавляем к таблицам дни недели и время для сводных таблиц.

# %%
# День недели
dates_all = pd.to_datetime(df_all_orders['Дата'])
df_all_orders['ДеньНедели'] = dates_all.dt.weekday_name

dates_buyed = pd.to_datetime(df_buyed_orders['Дата'])
df_buyed_orders['ДеньНедели'] = dates_buyed.dt.weekday_name

# Время - час
df_all_orders['ВремяОкругл'] = dates_all.dt.hour
df_buyed_orders['ВремяОкругл'] = dates_buyed.dt.hour

# %%
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Monday', 'ДеньНедели'] = 'Понедельник'
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Tuesday', 'ДеньНедели'] = 'Вторник'
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Wednesday', 'ДеньНедели'] = 'Среда'
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Thursday', 'ДеньНедели'] = 'Четверг'
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Friday', 'ДеньНедели'] = 'Пятница'
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Saturday', 'ДеньНедели'] = 'Суббота'
df_all_orders.loc[df_all_orders['ДеньНедели'] == 'Sunday', 'ДеньНедели'] = 'Воскресенье'

df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Monday', 'ДеньНедели'] = 'Понедельник'
df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Tuesday', 'ДеньНедели'] = 'Вторник'
df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Wednesday', 'ДеньНедели'] = 'Среда'
df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Thursday', 'ДеньНедели'] = 'Четверг'
df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Friday', 'ДеньНедели'] = 'Пятница'
df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Saturday', 'ДеньНедели'] = 'Суббота'
df_buyed_orders.loc[df_buyed_orders['ДеньНедели'] == 'Sunday', 'ДеньНедели'] = 'Воскресенье'

# %%
print(df_all_orders.shape)
print(df_buyed_orders.shape)
# Out:
# (431200, 40)
# (215876, 40)

# %% [markdown]
# Сохраним

# %%
df_all_orders.to_csv('df_all_orders_new.csv', index=False, sep=';', encoding='utf-8-sig')
df_buyed_orders.to_csv('df_buyed_orders_new.csv', index=False, sep=';', encoding='utf-8-sig')

# %% [markdown]
# ### Сводные таблицы по всем заказам.

# %%
pivot_Month = generate_table(df_all_orders, column_name='МесяцДатыЗаказа')
pivot_Group2 = generate_table(df_all_orders, column_name='Группа2')
pivot_CityShop = generate_table(df_all_orders, column_name='ГородМагазина')
pivot_Geo = generate_table(df_all_orders, column_name='Гео')
pivot_Delivery = generate_table(df_all_orders, column_name='МетодДоставки')
pivot_Payment = generate_table(df_all_orders, column_name='ФормаОплаты')
pivot_DayOfWeek = generate_table(df_all_orders, column_name='ДеньНедели')
pivot_Time = generate_table(df_all_orders, column_name='ВремяОкругл')

# %%
pivot_Month.sort_values('Выручка', ascending = False)
# Out:
#   МесяцДатыЗаказа    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 0               3  203987075         66211323  0.324586     997.413841
# 1               4  193096056         64649746  0.334806    1008.623586
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 0        3367        66383         213196                              3
# 1        3316        64097         218004                              3
#
#   Кол-во уникальных клиентов Ценность клиента
# 0                      52995             1249
# 1                      50695             1275

# %%
pivot_Group2.sort_values('Выручка', ascending = False)
# Out:
#                       Группа2    Выручка Абсолютная маржа     Маржа  \
# 0      КРУПНОГАБАРИТНЫЙ ТОВАР  138654014         43138521  0.311123
# 6                  ПОДГУЗНИКИ   64993978         19123084  0.294229
# 2                     ИГРУШКИ   59885282         14225993  0.237554
# 16                        104             5549
# 8                         104             4412
# ..                        ...              ...
# 53                          8             2991
# 15                          9             1754
# 57                          4             4197
# 58                          7             2213
# 61                          8             2111
#
# [63 rows x 11 columns]

# %%
pivot_Geo.sort_values('Выручка', ascending = False)
# Out:
#        Гео    Выручка Абсолютная маржа     Маржа  Средняя маржа Средний чек  \
# 1  Регионы  213872582         66993510  0.313240     958.419313        3284
# 0   Москва  141353854         49939125  0.353292    1064.232818        3399
# 2       МО   41856695         13928434  0.332765    1020.024460        3441
#
#   Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 1        69900         175480                              3
# 0        46925         202158                              4
# 2        13655          53562                              4
#
#   Кол-во уникальных клиентов Ценность клиента
# 1                      48465             1382
# 0                      34498             1448
# 2                       9713             1434

# %%
pivot_Delivery.sort_values('Выручка', ascending = False)
# Out:
#            МетодДоставки    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 1               Магазины  265451635         80023992  0.301464     924.566358
# 0             Курьерская   75499194         28965066  0.383647    1558.937890
# 5              Самовывоз   35286732         13937265  0.394972     712.757748
# 3             Pick point    9137342          3103435  0.339643     860.630893
# 2                    DPD    6202182          2083657  0.335955    1755.397641
# 4  Транспортная компания    5506046          2747654  0.499025    2747.654000
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 1        3376        86553         255742                              3
# 0        4513        18580         106276                              6
# 5        1924        19554          47298                              2
# 3        2756         3606          10810                              3
# 2        5875         1187           4549                              4
# 4        5493         1000           6525                              7
#
#   Кол-во уникальных клиентов Ценность клиента
# 1                      64066             1249
# 0                      14856             1950
# 5                      13633             1022
# 3                       3192              972
# 2                       1139             1829
# 4                        835             3291

# %%
pivot_Payment.sort_values('Выручка', ascending = False)
# Out:
#    ФормаОплаты    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 1  Безналичная  286274546         87951461  0.307228     952.432871
# 0     Наличная  110808585         42909608  0.387241    1125.173275
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 1        3406        92344         277623                              3
# 0        3186        38136         153577                              4
#
#   Кол-во уникальных клиентов Ценность клиента
# 1                      68809             1278
# 0                      28342             1514

# %%
pivot_DayOfWeek.sort_values('Выручка', ascending = False)
# Out:
#     ДеньНедели   Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 3  Понедельник  63054047         20791071  0.329734    1016.380084
# 0      Вторник  61227871         20214884  0.330158    1010.441068
# 1      Пятница  59258634         19479416  0.328719    1001.100627
# 2      Суббота  59119965         19577419  0.331147    1017.590259
# 6        Среда  54158888         17748722  0.327716     960.844630
# 4      Четверг  53148180         17051151  0.320823     928.762514
# 5  Воскресенье  47115546         15998407  0.339557    1104.099862
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 3        3373        20456          68628                              3
# 0        3400        20006          65312                              3
# 1        3379        19458          61245                              3
# 2        3341        19239          64667                              3
# ### Ниже таблица считается очень долго.

# %%
pivot_Phone = generate_table(df_all_orders, column_name='Телефон_new')

# %% [markdown]
# ### Сохраняем

# %%
pivot_Phone.to_csv('pivot_Phone_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_Month.to_csv('pivot_Month_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Group2.to_csv('pivot_Group2_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_CityShop.to_csv('pivot_CityShop_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Geo.to_csv('pivot_Geo_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Delivery.to_csv('pivot_Delivery_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Payment.to_csv('pivot_Payment_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_DayOfWeek.to_csv('pivot_DayOfWeek_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Time.to_csv('pivot_Time_all_orders.csv', index=False, sep=';', encoding='utf-8-sig')

# %% [markdown]
# ### Сводные таблицы по выкупленным товарам.

# %%
pivot_Month = generate_table(df_buyed_orders, column_name='МесяцДатыЗаказа')
pivot_Group2 = generate_table(df_buyed_orders, column_name='Группа2')
pivot_CityShop = generate_table(df_buyed_orders, column_name='ГородМагазина')
pivot_Geo = generate_table(df_buyed_orders, column_name='Гео')
pivot_Delivery = generate_table(df_buyed_orders, column_name='МетодДоставки')
pivot_Payment = generate_table(df_buyed_orders, column_name='ФормаОплаты')
pivot_DayOfWeek = generate_table(df_buyed_orders, column_name='ДеньНедели')
pivot_Time = generate_table(df_buyed_orders, column_name='ВремяОкругл')

# %%
pivot_Month.sort_values('Выручка', ascending = False)
# Out:
#   МесяцДатыЗаказа    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 1               4  117733366         36454988  0.309640     948.040153
# 0               3  115221559         33439121  0.290216     900.232090
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 1        3150        38453         115736                              3
# 0        3212        37145         100140                              3
#
#   Кол-во уникальных клиентов Ценность клиента
# 1                      32432             1124
# 0                      31706             1055

# %%
pivot_Group2.sort_values('Выручка', ascending = False)
# Out:
#                       Группа2    Выручка Абсолютная маржа     Маржа  \
# 2      КРУПНОГАБАРИТНЫЙ ТОВАР  101678894         30759158  0.302513
# 5                  ПОДГУЗНИКИ   35122199          9431073  0.268522
# 1                     ИГРУШКИ   35028032          7942742  0.226754
# 0          ТЕКСТИЛЬ, ТРИКОТАЖ   25955589          8750494  0.337133
# 10            ДЕТСКОЕ ПИТАНИЕ   11039231          6712276  0.608038
# 9        ТОВАРЫ ДЛЯ КОРМЛЕНИЯ    7234398          1450956  0.200563
# 3                       ОБУВЬ    7135771          2342251  0.328241
# 6           КОСМЕТИКА/ГИГИЕНА    4566475          1274706  0.279144
# 8    КАНЦТОВАРЫ, КНИГИ, ДИСКИ    2504180           644096  0.257208
# 11        ТОВАРЫ ДЛЯ ЖИВОТНЫХ    2426923           488774  0.201397
# 4        СОПУТСТВУЮЩИЕ ТОВАРЫ     195532            62324  0.318741
# 7              ЖЕНСКИЕ ШТУЧКИ      55315            32053  0.579463
# 12  ТЕХНИКА И ТОВАРЫ ДЛЯ ДОМА      12385             3207  0.258942
#
#     Средняя маржа Средний чек Кол-во чеков Кол-во товаров  \
# 2     1984.589845        7116        15499          17629
# 5      506.366336        2698        18625          25704
# 1      327.117582        2214        24281          52944
# 0      621.175126        2870        14087          35851
# 10     965.656165        2954         6951          27822
# 9      187.631708        2779         7733          14213
# 3      520.268992        2449         4502           6174
# 6      164.925087        2717         7729          19093
# 8      145.426959        2186         4429          11922
# 11     300.969212        2211         1624           3619
# 4      154.650124        2787          403            492
# 7      168.700000        2953          190            391
# 12     168.789474        3712           19             22
#
#    Среднее кол-во товаров в  чеке Кол-во уникальных клиентов Ценность клиента
# 2                               1                      14258             2157
# 5                               1                      14349              657
# 1                               2                      21263              374
# 0                               3                      11429              766
# 10                              4                       5221             1286
# 9                               2                       6933              209
# 3                               1                       4005              585
# 6                               2                       6579              194
# 8                               3                       4008              161
# 11                              2                       1347              363
# 4                               1                        391              159
# 7                               2                        176              182
# 12                              1                         19              169

# %%
pivot_CityShop.sort_values('Выручка', ascending = False)
# Out:
#        ГородМагазина    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 0   ИнтернетДоставка  209159989         62114412  0.296971     848.163585
# 3             Калуга    2648099           891458  0.336641    3623.813008
# 14    Ростов-на-Дону    1483665           475179  0.320274    3683.558140
# 17            Москва    1450969           502780  0.346513    2371.603774
# 7               Омск    1409911           421376  0.298867    4131.137255
# ..               ...        ...              ...       ...            ...
# 36            Мытищи      77343            33535  0.433588    2395.357143
# 13           Сергиев      56912            15042  0.264303    1880.250000
# 56             Пенза      52515            16787  0.319661    4196.750000
# 58       Стерлитамак      47684            15494  0.324931    2213.428571
# 61        Набережные      45814            16887  0.368599    1876.333333
#
#    Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 0         2950        73234         213299                              3
# 3        10828          246            264                              1
# 14       11694          129            136                              1
# 17        6905          212            222                              1
# 7        14417          102            115                              1
# ..         ...          ...            ...                            ...
# 36        5742           14             15                              1
# 13        7114            8              8                              1
# 56       13129            4              4                              1
# 58        6812            7              7                              1
# 61        8046            9              9                              1
#
#    Кол-во уникальных клиентов Ценность клиента
# 0                       55919             1111
# 3                         211             4225
# 14                         94             5055
# 17                        207             2429
# 7                          94             4483
# ..                        ...              ...
# 36                         14             2395
# 13                          8             1880
# 56                          4             4197
# 58                          7             2213
# 61                          8             2111
#
# [63 rows x 11 columns]

# %%
pivot_Geo.sort_values('Выручка', ascending = False)
# Out:
#        Гео    Выручка Абсолютная маржа     Маржа  Средняя маржа Средний чек  \
# 0  Регионы  146478228         42388730  0.289386    1035.589026        3684
# 2   Москва   60274267         19093621  0.316779     757.833737        2483
# 1       МО   26202428          8411758  0.321030     888.159434        2858
#
#   Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 0        40932          99092                              2
# 2        25195          84878                              3
# 1         9471          31906                              3
#
#   Кол-во уникальных клиентов Ценность клиента
# 0                      32492             1305
# 2                      19168              996
# 1                       6955             1209

# %%
pivot_Delivery.sort_values('Выручка', ascending = False)
# Out:
#   МетодДоставки    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 0      Магазины  232954924         69894109  0.300033      924.54971
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 0        3180        75598         215876                              3
#
#   Кол-во уникальных клиентов Ценность клиента
# 0                      58031             1204

# %%
pivot_Payment.sort_values('Выручка', ascending = False)
# Out:
#    ФормаОплаты    Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 0  Безналичная  232934430         69888574  0.300035     924.488723
# 1     Наличная      20494             5535  0.270079    5535.000000
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 0        3180        75597         215874                              3
# 1       10247            1              2                              2
#
#   Кол-во уникальных клиентов Ценность клиента
# 0                      58030             1204
# 1                          1             5535

# %%
pivot_DayOfWeek.sort_values('Выручка', ascending = False)
# Out:
#     ДеньНедели   Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 3  Понедельник  36898832         11119141  0.301341     922.061614
# 2      Суббота  35508403         10760804  0.303050     960.614533
# 0      Вторник  34346725         10233800  0.297956     905.005306
# 1      Пятница  33406286         10037098  0.300455     939.803184
# 6        Среда  32340224          9607763  0.297084     868.851782
# 4      Четверг  32078724          9398226  0.292974     855.550842
# 5  Воскресенье  28375732          8737276  0.307914    1051.923429
#
#   Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 3        3163        12059          34561                              3
# 2        3255        11202          32837                              3
# 0        3131        11308          31295                              3
# 1        3256        10680          28885                              3
# 6        3012        11058          33146                              3
# 4        3013        10985          33865                              3
# 5        3520         8306          21287                              3
#
#   Кол-во уникальных клиентов Ценность клиента
# 3                      11157              997
# 2                      10344             1040
# 0                      10534              972
# 1                       9934             1010
# 6                      10270              936
# 4                      10212              920
# 5                       7832             1116

# %%
pivot_Time.sort_values('Выручка', ascending = False)
# Out:
#    ВремяОкругл   Выручка Абсолютная маржа     Маржа  Средняя маржа  \
# 4           14  17733376          5334875  0.300838     959.509892
# 7           15  17480402          5239906  0.299759     912.557645
# 0           12  17475687          5228046  0.299161     987.728320
# 9           18  17450683          5187900  0.297289     972.245127
# 5           17  16697584          5074260  0.303892     943.872768
# 8           16  16366949          5028168  0.307215     959.940435
# 1           11  15205033          4554703  0.299552     955.064584
# 10          19  15193385          4591157  0.302181     985.226824
# 3           10  14045996          4156267  0.295904     942.250510
# 11          20  13123735          3878789  0.295555     870.659708
# 6           13  12801665          3797306  0.296626     947.431637
# 12          21  12290682          3615395  0.294157     844.915868
# 17          22  11348232          3395334  0.299195     825.111543
# 13          23  10220206          3111593  0.304455     852.491233
# 14           2   8189371          2491969  0.304293     827.346946
# 22           0   4305379          1362134  0.316380     963.319661
# 2            9   3695093          1111236  0.300733     950.586826
# 19           8   3362146           993221  0.295413     859.931602
# 21           7   2287963           669315  0.292538     952.083926
# 18           6   1182135           345113  0.291940     961.317549
# 15           4   1119740           332264  0.296733     849.780051
# 20           3    745483           213475  0.286358     733.591065
# 16           5    632149           181185  0.286618     858.696682
# 23           1      1849              499  0.269876     499.000000
#
#    Средний чек Кол-во чеков Кол-во товаров Среднее кол-во товаров в  чеке  \
# 4         3298         5560          15580                              3
# 7         3159         5742          15745                              3
# 0         3393         5293          14858                              3
# 9         3375         5336          14182                              3
# 5         3214         5376          15704                              3
# 8         3215         5238          14539                              3
# 1         3301         4769          12923                              3
# 10        3347         4660          13081                              3
# 3         3266         4411          11350                              3
# 11        3028         4455          12458                              3
# 6         3287         4008          11274                              3
# 12        2983         4279          12550                              3
# 17        2864         4115          12174                              3
# 13        2884         3650          12087                              3
# 14        2822         3012          11394                              4
# 22        3135         1414           4141                              3
# 2         3245         1169           3120                              3
# 19        2998         1155           2826                              2
# 21        3337          703           1910                              3
# 18        3344          359            871                              2
# 15        2990          391           1473                              4
# 20        2675          291            963                              3
# 16        3176          211            672                              3
# 23        1898            1              1                              1
#
#    Кол-во уникальных клиентов Ценность клиента
# 4                        5301             1006
# 7                        5501              953
# 0                        5060             1033
# 9                        5091             1019
# 5                        5136              988
# 8                        5002             1005
# 1                        4570              997
# 10                       4464             1028
# 3                        4202              989
# 11                       4286              905
# 6                        3852              986
# 12                       4093              883
# 17                       3906              869
# 13                       3476              895
# 14                       2815              885
# 22                       1385              983
# 2                        1148              968
# 19                       1131              878
# 21                        692              967
# 18                        354              975
# 15                        388              856
# 20                        280              762
# 16                        207              875
# 23                          1              499

# %%
pivot_Phone_buyed = generate_table(df_buyed_orders, column_name='Телефон_new')
#58031

# %% [markdown]
# ### Сохраняем

# %%
pivot_Phone_buyed.to_csv('pivot_Phone_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')

# %%
pivot_Month.to_csv('pivot_Month_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Group2.to_csv('pivot_Group2_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_CityShop.to_csv('pivot_CityShop_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Geo.to_csv('pivot_Geo_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Delivery.to_csv('pivot_Delivery_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Payment.to_csv('pivot_Payment_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_DayOfWeek.to_csv('pivot_DayOfWeek_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
pivot_Time.to_csv('pivot_Time_buyed_orders.csv', index=False, sep=';', encoding='utf-8-sig')
